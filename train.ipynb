# %%
# !nvidia-smi
# Out:
# Fri Jun  3 19:29:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    30W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/ColabNotebooks/Ro-InceptionNetv4/train.py --basedir '/content/drive/MyDrive/ColabNotebooks/Ro-InceptionNetv4'
# Out:
# Trainning Epoch  1: 100% 334/334 [15:45<00:00,  2.83s/it]
# RESULT Epoch  1, Train Loss:4.718341, Train Acc.:0.012299
# Trainning Epoch  2: 100% 334/334 [03:21<00:00,  1.66it/s]
# RESULT Epoch  2, Train Loss:4.676435, Train Acc.:0.012149
# Trainning Epoch  3: 100% 334/334 [03:21<00:00,  1.66it/s]
# RESULT Epoch  3, Train Loss:4.653329, Train Acc.:0.014549
# Trainning Epoch  4: 100% 334/334 [03:21<00:00,  1.66it/s]
# RESULT Epoch  4, Train Loss:4.628782, Train Acc.:0.012749
# Trainning Epoch  5: 100% 334/334 [03:21<00:00,  1.66it/s]
# RESULT Epoch  5, Train Loss:4.563279, Train Acc.:0.018899
# Trainning Epoch  6: 100% 334/334 [03:20<00:00,  1.66it/s]
# RESULT Epoch  6, Train Loss:4.514378, Train Acc.:0.024599
# Trainning Epoch  7: 100% 334/334 [03:20<00:00,  1.67it/s]
# RESULT Epoch  7, Train Loss:4.455188, Train Acc.:0.031048
# Trainning Epoch  8: 100% 334/334 [03:20<00:00,  1.67it/s]
# RESULT Epoch  8, Train Loss:4.302506, Train Acc.:0.042148
# ...

# %%
# !python /content/drive/MyDrive/ColabNotebooks/Ro-InceptionNetv4/eval.py \
--modeldir '/content/drive/MyDrive/ColabNotebooks/Ro-InceptionNetv4/checkpoint/model_03-06-2022_22:30:32.pth' \
--basedir '/content/drive/MyDrive/ColabNotebooks/Ro-InceptionNetv4'
# Out:
# Acc. for TRAIN SET:  17% 583/3334 [02:22<10:56,  4.19it/s]
